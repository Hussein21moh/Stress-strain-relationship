# %% [markdown]
# <a href="https://colab.research.google.com/github/Hussein21moh/Stress-strain-relationship/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
radius = 3.0
height = 5.5
volume=math.pi*radius**2*height
print(f'volume : {volume:.2f} cm3')
# Out:
# volume : 155.51 cm3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path="/Data Available Active Brain.csv"
df=pd.read_csv(path)
df = df.set_index('Borehole_ID')
df.head(47)
# Out:
#              Depth_m  Bulk_Density_gm_cm3  Water_Content_Pct  \
# Borehole_ID
# BH-04            7.5                2.194               2.99
# BH-04           12.0                2.206               2.90
# BH-05            9.0                2.204               2.88
# BH-05           13.5                2.223               2.63
# BH-05           18.0                2.220               2.60
# BH-06           10.5                2.176               3.32
# BH-06           15.0                2.185               3.12
# BH-06           20.0                2.205               2.89
# BH-07            7.5                2.219               2.92
# BH-07           12.0                2.201               2.86
# BH-08            4.5                2.199               3.65
# BH-08           10.5                2.196               2.94
# BH-08           16.5                2.195               2.75
# BH-09            4.5                2.205               2.87
# ...

# %%
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='Borehole_ID'>, <Axes: xlabel='Borehole_ID'>,
#        <Axes: xlabel='Borehole_ID'>, <Axes: xlabel='Borehole_ID'>,
#        <Axes: xlabel='Borehole_ID'>, <Axes: xlabel='Borehole_ID'>,
#        <Axes: xlabel='Borehole_ID'>, <Axes: xlabel='Borehole_ID'>],
#       dtype=object)

# %%
df.plot.scatter(x='Depth_m', y='Porosity', s=50)
df.plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1066/1673337759.py in <cell line: 0>()
#       1 df.plot.scatter(x='Depth_m', y='Porosity', s=50)
# ----> 2 df.plot.scatter()
#
# TypeError: PlotAccessor.scatter() missing 2 required positional arguments: 'x' and 'y'
